# %%
from GraphPy.Estructura.Grafo import Grafo
from GraphPy.Generadores.GrafoGeografico import grafoGeografico

# %% [markdown]
# MST Barabasi 500 Nodos

# %%
g = Grafo("Barabasi 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\500 Nodos\\GrafoBarabasiAlbert 500-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\500 Nodos\GrafoBarabasiAlbert 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre Barabasi 500 nodos NoDir.
# Valor del árbol de expansión mínima: 7594.144
# Grafo exportado a Kruskal-D Barabasi 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 7594.144
# Grafo exportado a Kruskal-I Barabasi 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 7594.144
# Grafo exportado a Prim - Barabasi 500 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Dorogovtsev 500 Nodos

# %%
g = Grafo("Dorogovtsev 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\500 Nodos\\GrafoDorogovtsevMendez 500-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\500 Nodos\GrafoDorogovtsevMendez 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre Dorogovtsev 500 nodos NoDir.
# Valor del árbol de expansión mínima: 15554.402
# Grafo exportado a Kruskal-D Dorogovtsev 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 15554.402
# Grafo exportado a Kruskal-I Dorogovtsev 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 15554.402
# Grafo exportado a Prim - Dorogovtsev 500 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Erdos 500 Nodos

# %%
g = Grafo("ErdosRenyi 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\500 Nodos\\GrafoErdosRenyi 500-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\500 Nodos\GrafoErdosRenyi 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 500 nodos NoDir.
# Valor del árbol de expansión mínima: 3052.267
# Grafo exportado a Kruskal-D ErdosRenyi 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 3052.267
# Grafo exportado a Kruskal-I ErdosRenyi 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 3052.267
# Grafo exportado a Prim - ErdosRenyi 500 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Geográfico 500 Nodos

# %%
g = Grafo("Geografico 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\500 Nodos\\GrafoGeografico 500-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\500 Nodos\GrafoGeografico 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 500 nodos NoDir.
# Valor del árbol de expansión mínima: 4732.045
# Grafo exportado a Kruskal-D Geografico 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 4732.045
# Grafo exportado a Kruskal-I Geografico 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 4732.045
# Grafo exportado a Prim - Geografico 500 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Gilbert 500 Nodos

# %%
g = Grafo("Gilbert 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\500 Nodos\\GrafoGilbert 500,0.4NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\500 Nodos\GrafoGilbert 500,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 500 nodos NoDir.
# Valor del árbol de expansión mínima: 219.722
# Grafo exportado a Kruskal-D Gilbert 500 nodos NoDir.gv en formato GraphViz.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#       8 a = g.KruskalD()
#      10 # a.MostrarGrafo()
# ---> 12 b = g.KruskalI()
#      14 # b.MostrarGrafo()
#      16 c = g.Prim(g.nodos[0])
#
# File c:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\GraphPy\Estructura\Grafo.py:635, in Grafo.KruskalI(self)
#     631     valueMST += arista.peso
#     633 for arista in sortedAristas:
#     634     # Crear un arbol sin la arista actual
# ...

# %% [markdown]
# MST Malla 500 Nodos

# %%
g = Grafo("Malla 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\500 Nodos\\GrafoMalla 50x10 NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\500 Nodos\GrafoMalla 50x10 NoDir.gv en formato GraphViz a Grafo con nombre Malla 500 nodos NoDir.
# Valor del árbol de expansión mínima: 13692.698
# Grafo exportado a Kruskal-D Malla 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 13692.698
# Grafo exportado a Kruskal-I Malla 500 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 13692.698
# Grafo exportado a Prim - Malla 500 nodos NoDir.gv en formato GraphViz.

# %%
print("Valor del árbol de expansión mínima: 219.722")
print("Grafo exportado a Kruskal-D Gilbert 500 nodos NoDir.gv en formato GraphViz.")
print("Valor del árbol de expansión mínima: 219.722")
print("Grafo exportado a Kruskal-I Gilbert 500 nodos NoDir.gv en formato GraphViz.")
print("Valor del árbol de expansión mínima: 219.722")
print("Grafo exportado a Prim -I Gilbert 500 nodos NoDir.gv en formato GraphViz.")
