# %%
from GraphPy.Estructura.Grafo import Grafo
from GraphPy.Generadores.GrafoGeografico import grafoGeografico
import cv2

# %% [markdown]
# Hiperparámetros

# %%
# Configuración de Pygame
ANCHO, ALTO = 1600, 1200
BLANCO = (255, 255, 255)
NEGRO = (0, 0, 0)
AZUL = (0, 0, 255)
ROJO = (255, 0, 0)

# Parámetros del algoritmo Spring
C1 = 1.5 # Constante de atracción
C2 = 400.0  # Constante de repulsión
C3 = 0.05  # Coeficiente de movimiento
ITERACIONES = 1000

# %% [markdown]
# Barabasi 500 Nodos

# %%
g = Grafo("Barabasi 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\500 Nodos\\GrafoBarabasiAlbert 500-nodos NoDir.gv")

g.AsiganarValoresXY()

g.SPRING(ANCHO, ALTO, BLANCO, NEGRO, AZUL, C1, C2, C3, ITERACIONES)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\500 Nodos\GrafoBarabasiAlbert 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre Barabasi 500 nodos NoDir.
# Captura guardada como: Barabasi 500 nodos NoDir.png

# %% [markdown]
# Dorogovtsev 500 Nodos

# %%
g = Grafo("Dorogovtsev 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\500 Nodos\\GrafoDorogovtsevMendez 500-nodos NoDir.gv")

g.AsiganarValoresXY()

g.SPRING(ANCHO, ALTO, BLANCO, NEGRO, AZUL, C1, C2, C3, ITERACIONES)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\500 Nodos\GrafoDorogovtsevMendez 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre Dorogovtsev 500 nodos NoDir.
# Captura guardada como: Dorogovtsev 500 nodos NoDir.png

# %% [markdown]
# Erdos 500 Nodos

# %%
g = Grafo("ErdosRenyi 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\500 Nodos\\GrafoErdosRenyi 500-nodos NoDir.gv")

g.AsiganarValoresXY()

g.SPRING(ANCHO, ALTO, BLANCO, NEGRO, AZUL, C1, C2, C3, ITERACIONES)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\500 Nodos\GrafoErdosRenyi 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 500 nodos NoDir.
# Captura guardada como: ErdosRenyi 500 nodos NoDir.png

# %% [markdown]
# Geográfico 500 Nodos

# %%
g = Grafo("Geografico 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\500 Nodos\\GrafoGeografico 500-nodos NoDir.gv")

g.AsiganarValoresXY()

g.SPRING(ANCHO, ALTO, BLANCO, NEGRO, AZUL, C1, C2, C3, ITERACIONES)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\500 Nodos\GrafoGeografico 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 500 nodos NoDir.
# Captura guardada como: Geografico 500 nodos NoDir.png

# %% [markdown]
# Gilbert 500 Nodos

# %%
g = Grafo("Gilbert 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\500 Nodos\\GrafoGilbert 500,0.4NoDir.gv")

g.AsiganarValoresXY()

g.SPRING(ANCHO, ALTO, BLANCO, NEGRO, AZUL, C1, C2, C3, ITERACIONES)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\500 Nodos\GrafoGilbert 500,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 500 nodos NoDir.
# Captura guardada como: Gilbert 500 nodos NoDir.png

# %% [markdown]
# Malla 500 Nodos

# %%
g = Grafo("Malla 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\500 Nodos\\GrafoMalla 50x10 NoDir.gv")

g.AsiganarValoresXY()

g.SPRING(ANCHO, ALTO, BLANCO, NEGRO, AZUL, C1, C2, C3, ITERACIONES)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\500 Nodos\GrafoMalla 50x10 NoDir.gv en formato GraphViz a Grafo con nombre Malla 500 nodos NoDir.
# Captura guardada como: Malla 500 nodos NoDir.png
