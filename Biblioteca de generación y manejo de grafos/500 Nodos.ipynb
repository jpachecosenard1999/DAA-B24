# %%
from GraphPy.Estructura.Grafo import Grafo
from GraphPy.Generadores.GrafoGeografico import grafoGeografico
from GraphPy.Generadores.GrafoErdosRenyi import grafoErdosRenyi

# %% [markdown]
# Dijkstra Barabasi 500 Nodos

# %%
g = Grafo("BarabasiAlbert 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\500 Nodos\\GrafoBarabasiAlbert 500-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos Dijkstra\500 Nodos\GrafoBarabasiAlbert 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre BarabasiAlbert 500 nodos NoDir.
# Grafo exportado a Dijkstra - BarabasiAlbert 500 nodos NoDir.gv con etiquetas y camino resaltado en formato GraphViz.
# Nodo: N-26(150.95251059014913)
# Arista: N-26(150.95251059014913)-N-23(136.81079081230055)
# Nodo: N-120(356.09473168252237)
# Arista: N-120(356.09473168252237)-N-114(323.4635933680415)
# Nodo: N-482(1106.8432469512568)
# Arista: N-482(1106.8432469512568)-N-477(1090.0860872701762)
# Nodo: N-337(793.9073620781033)
# Arista: N-337(793.9073620781033)-N-327(760.6559967727976)
# Nodo: N-164(392.2590755003627)
# Arista: N-164(392.2590755003627)-N-165(379.58842657952977)
# Nodo: N-404(991.3802596174628)
# Arista: N-404(991.3802596174628)-N-411(987.4046736018665)
# Nodo: N-440(1055.1083144028576)
# ...

# %% [markdown]
# Dijkstra Dorogovtsev 500 Nodos

# %%
g = Grafo("Dorogovtsev 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\500 Nodos\\GrafoDorogovtsevMendez 500-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos Dijkstra\500 Nodos\GrafoDorogovtsevMendez 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre Dorogovtsev 500 nodos NoDir.
# Grafo exportado a Dijkstra - Dorogovtsev 500 nodos NoDir.gv con etiquetas y camino resaltado en formato GraphViz.
# Nodo: N-120(159.63915893009846)
# Arista: N-120(159.63915893009846)-N-49(148.53489653229292)
# Nodo: N-149(96.94545401820764)
# Arista: N-149(96.94545401820764)-N-2(47.281924401530695)
# Nodo: N-60(21.3756739991109)
# Arista: N-60(21.3756739991109)-N-13(16.052163754110648)
# Nodo: N-498(150.13104385920673)
# Arista: N-498(150.13104385920673)-N-57(119.64100247967193)
# Nodo: N-156(110.91882156852465)
# Arista: N-156(110.91882156852465)-N-5(78.01370835925246)
# Nodo: N-168(145.0140059587665)
# Arista: N-168(145.0140059587665)-N-18(56.38960968475113)
# Nodo: N-484(89.50941094266244)
# ...

# %% [markdown]
# Dijkstra Erdos 500 Nodos

# %%
g = grafoErdosRenyi(500, 5000, dirigido = False)

g.MostrarGrafo()

g.Guardar()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# Nodo: N-0
# Arista: N-0-N-74
# Arista: N-0-N-482
# Arista: N-0-N-276
# Arista: N-0-N-221
# Arista: N-0-N-376
# Arista: N-0-N-455
# Arista: N-0-N-40
# Arista: N-0-N-76
# Arista: N-0-N-401
# Arista: N-0-N-182
# Arista: N-0-N-122
# Nodo: N-1
# Arista: N-1-N-464
# Arista: N-1-N-75
# Arista: N-1-N-134
# Arista: N-1-N-481
# Arista: N-1-N-43
# Arista: N-1-N-360
# Arista: N-1-N-486
# Arista: N-1-N-263
# Arista: N-1-N-340
# Arista: N-1-N-287
# Arista: N-1-N-187
# Arista: N-1-N-377
# Arista: N-1-N-15
# Nodo: N-2
# Arista: N-2-N-347
# Arista: N-2-N-156
# Arista: N-2-N-163
# Arista: N-2-N-361
# Arista: N-2-N-111
# Arista: N-2-N-109
# Nodo: N-3
# Arista: N-3-N-191
# Arista: N-3-N-74
# Arista: N-3-N-63
# Arista: N-3-N-459
# Arista: N-3-N-491
# Arista: N-3-N-170
# Arista: N-3-N-488
# Arista: N-3-N-67
# Arista: N-3-N-98
# Nodo: N-4
# Arista: N-4-N-249
# Arista: N-4-N-309
# Arista: N-4-N-226
# Arista: N-4-N-187
# Arista: N-4-N-490
# Arista: N-4-N-59
# Arista: N-4-N-254
# Arista: N-4-N-12
# ...

# %% [markdown]
# Dijkstra Geográfico 500 Nodos

# %%
g = Grafo("Geografico 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\500 Nodos\\GrafoGeografico 500-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos Dijkstra\500 Nodos\GrafoGeografico 500-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 500 nodos NoDir.
# Grafo exportado a Dijkstra - Geografico 500 nodos NoDir.gv con etiquetas y camino resaltado en formato GraphViz.
# Nodo: N-454(75.32749799092576)
# Arista: N-454(75.32749799092576)-N-312(59.98192620140452)
# Nodo: N-373(164.21612828604714)
# Arista: N-373(164.21612828604714)-N-456(155.4496048371366)
# Nodo: N-423(136.11036478664394)
# Arista: N-423(136.11036478664394)-N-392(133.3658964792013)
# Nodo: N-357(106.01967101609392)
# Arista: N-357(106.01967101609392)-N-317(94.62567902759423)
# Nodo: N-367(81.5070559417578)
# Arista: N-367(81.5070559417578)-N-464(69.763812223634)
# Nodo: N-310(218.574172004127)
# Arista: N-310(218.574172004127)-N-21(194.33435563809508)
# Nodo: N-193(149.72194355320318)
# ...

# %% [markdown]
# Dijkstra Gilbert 500 Nodos

# %%
g = Grafo("Gilbert 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\500 Nodos\\GrafoGilbert 500,0.4NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos Dijkstra\500 Nodos\GrafoGilbert 500,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 500 nodos NoDir.
# Grafo exportado a Dijkstra - Gilbert 500 nodos NoDir.gv con etiquetas y camino resaltado en formato GraphViz.
# Nodo: N-336(2.2366177773777474)
# Arista: N-336(2.2366177773777474)-N-65(2.0937270994179635)
# Nodo: N-3(0.8231935796336853)
# Arista: N-3(0.8231935796336853)-N-121(0.7395631973684091)
# Nodo: N-434(3.224810777761322)
# Arista: N-434(3.224810777761322)-N-252(2.310948060991691)
# Nodo: N-372(2.1679625819931214)
# Arista: N-372(2.1679625819931214)-N-259(1.8134606723835156)
# Nodo: N-32(2.2324516500340175)
# Arista: N-32(2.2324516500340175)-N-315(1.4901537607613036)
# Nodo: N-368(1.5611385861819316)
# Arista: N-368(1.5611385861819316)-N-308(1.4087240946405344)
# Nodo: N-140(1.2102847066439604)
# ...

# %% [markdown]
# Dijkstra Malla 500 Nodos

# %%
g = Grafo("Malla 500 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\500 Nodos\\GrafoMalla 50x10 NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos Dijkstra\500 Nodos\GrafoMalla 50x10 NoDir.gv en formato GraphViz a Grafo con nombre Malla 500 nodos NoDir.
# Grafo exportado a Dijkstra - Malla 500 nodos NoDir.gv con etiquetas y camino resaltado en formato GraphViz.
# Nodo: N28,3(951.6199211703287)
# Arista: N28,3(951.6199211703287)-N27,3(942.300277872986)
# Nodo: N2,5(224.4812930906221)
# Arista: N2,5(224.4812930906221)-N3,5(196.28614639116847)
# Nodo: N45,9(1670.7655409208064)
# Arista: N45,9(1670.7655409208064)-N44,9(1610.8965124143763)
# Nodo: N0,2(134.2560166769534)
# Arista: N0,2(134.2560166769534)-N0,1(47.66168369097564)
# Nodo: N42,8(1523.2689181155179)
# Arista: N42,8(1523.2689181155179)-N41,8(1458.2325707163438)
# Nodo: N23,9(911.7321708630726)
# Arista: N23,9(911.7321708630726)-N22,9(892.3783419184475)
# Nodo: N2,8(312.84007116671893)
# Arista: N2,8(312.84007116671893)-N2,7(257.51787090230886)
# ...
