# %%
from GraphPy.Estructura.Grafo import Grafo
from GraphPy.Generadores.GrafoGeografico import grafoGeografico

# %% [markdown]
# Dijkstra Barabasi 30 Nodos

# %%
g = Grafo("BarabasiAlbert 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\30 Nodos\\GrafoBarabasiAlbert 30-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos Dijkstra\30 Nodos\GrafoBarabasiAlbert 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre BarabasiAlbert 30 nodos NoDir.
# Grafo exportado a Dijkstra - BarabasiAlbert 30 nodos NoDir.gv con etiquetas y camino resaltado en formato GraphViz.
# Nodo: N-17(67.7322655842359)
# Arista: N-17(67.7322655842359)-N-7(32.96181751479203)
# Nodo: N-9(56.67522735464586)
# Arista: N-9(56.67522735464586)-N-6(32.17416208993201)
# Nodo: N-28(90.48143132548782)
# Arista: N-28(90.48143132548782)-N-23(78.53141627574132)
# Nodo: N-7(32.96181751479203)
# Arista: N-7(32.96181751479203)-N-6(32.17416208993201)
# Nodo: N-15(42.52590746621557)
# Arista: N-15(42.52590746621557)-N-7(32.96181751479203)
# Nodo: N-2(1.3180775061156558)
# Arista: N-2(1.3180775061156558)-N-0
# Nodo: N-14(51.54762869965605)
# Arista: N-14(51.54762869965605)-N-1(4.0787171451740045)
# Nodo: N-18(89.08064937985625)
# ...

# %% [markdown]
# Dijkstra Dorogovtsev 30 Nodos

# %%
g = Grafo("Dorogovtsev 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\30 Nodos\\GrafoDorogovtsevMendez 30-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos Dijkstra\30 Nodos\GrafoDorogovtsevMendez 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Dorogovtsev 30 nodos NoDir.
# Grafo exportado a Dijkstra - Dorogovtsev 30 nodos NoDir.gv con etiquetas y camino resaltado en formato GraphViz.
# Nodo: N-1(84.32330305692453)
# Arista: N-1(84.32330305692453)-N-0
# Nodo: N-5(101.72630832771748)
# Arista: N-5(101.72630832771748)-N-2(56.80466597281297)
# Nodo: N-6(11.073280304039557)
# Arista: N-6(11.073280304039557)-N-0
# Nodo: N-16(72.05735621938643)
# Arista: N-16(72.05735621938643)-N-10(19.2613820354715)
# Nodo: N-14(31.277810648276418)
# Arista: N-14(31.277810648276418)-N-3(10.948259575322872)
# Nodo: N-26(114.63738631782266)
# Arista: N-26(114.63738631782266)-N-2(56.80466597281297)
# Nodo: N-2(56.80466597281297)
# Arista: N-2(56.80466597281297)-N-0
# Nodo: N-23(86.46627305209994)
# Arista: N-23(86.46627305209994)-N-0
# ...

# %% [markdown]
# Dijkstra Erdos 30 Nodos

# %%
g = Grafo("ErdosRenyi 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\30 Nodos\\GrafoErdosRenyi 30-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos Dijkstra\30 Nodos\GrafoErdosRenyi 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 30 nodos NoDir.
# Grafo exportado a Dijkstra - ErdosRenyi 30 nodos NoDir.gv con etiquetas y camino resaltado en formato GraphViz.
# Nodo: N-5(40.37547130458985)
# Arista: N-5(40.37547130458985)-N-25(32.4980002125836)
# Nodo: N-7(127.45090108365048)
# Arista: N-7(127.45090108365048)-N-25(32.4980002125836)
# Nodo: N-17(160.59211525563927)
# Arista: N-17(160.59211525563927)-N-13(70.74078939898892)
# Nodo: N-18(21.65562196541153)
# Arista: N-18(21.65562196541153)-N-0
# Nodo: N-23(54.862188487312395)
# Arista: N-23(54.862188487312395)-N-0
# Nodo: N-3(95.29651727781197)
# Arista: N-3(95.29651727781197)-N-22(33.844863688157886)
# Nodo: N-10(62.208903597245474)
# Arista: N-10(62.208903597245474)-N-15(61.0736622412726)
# Nodo: N-21(91.60604249915228)
# ...

# %% [markdown]
# Dijkstra Geográfico 30 Nodos

# %%
g = grafoGeografico(30, .99, dirigido = True)

g.MostrarGrafo()

g.Guardar()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 g = grafoGeografico(500, .99, dirigido = True)
#       3 g.MostrarGrafo()
#       5 g.Guardar()
#
# File c:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\GraphPy\Generadores\GrafoGeografico.py:29, in grafoGeografico(n, r, dirigido)
#      27 dist = math.dist([nodo.X, nodo.Y], [nodoDestino.X, nodoDestino.Y])
#      28 if(dist <= r):
# ---> 29     arco1 = Arista(nodo, nodoDestino)
#      30     arco2 = Arista(nodoDestino, nodo)
#      31     if(dirigido == True and grafo.ExisteArco(arco1) == False):
#
# File c:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\GraphPy\Estructura\Arista.py:3, in Arista.__init__(self, nodoOrigen, nodoDestino, peso)
#       1 class Arista:
# ...

# %% [markdown]
# Dijkstra Gilbert 30 Nodos

# %%
g = Grafo("Gilbert 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\30 Nodos\\GrafoGilbert 30,0.4NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()

# %% [markdown]
# Dijkstra Malla 30 Nodos

# %%
g = Grafo("Malla 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\30 Nodos\\GrafoMalla 10x3 NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
