# %%
from GraphPy.Estructura.Grafo import Grafo

# %% [markdown]
# BFS Barabasi 30 Nodos

# %%
g = Grafo("BarabasiAlbert 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoBarabasiAlbert 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoBarabasiAlbert 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre BarabasiAlbert 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-28
# Arista: N-28-N-20
# Nodo: N-27
# Arista: N-27-N-16
# Nodo: N-5
# Arista: N-5-N-4
# Nodo: N-11
# Arista: N-11-N-3
# Nodo: N-12
# Arista: N-12-N-11
# Nodo: N-8
# Arista: N-8-N-5
# Nodo: N-16
# Arista: N-16-N-13
# Nodo: N-18
# Arista: N-18-N-14
# Nodo: N-13
# Arista: N-13-N-4
# Nodo: N-26
# Arista: N-26-N-24
# Nodo: N-17
# Arista: N-17-N-7
# Nodo: N-6
# Arista: N-6-N-2
# Nodo: N-25
# Arista: N-25-N-20
# Nodo: N-2
# Arista: N-2-N-0
# Nodo: N-9
# Arista: N-9-N-5
# Nodo: N-21
# Arista: N-21-N-11
# Nodo: N-29
# Arista: N-29-N-21
# Nodo: N-7
# Arista: N-7-N-4
# Nodo: N-19
# Arista: N-19-N-17
# Nodo: N-15
# Arista: N-15-N-7
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-22
# Arista: N-22-N-10
# Nodo: N-14
# ...

# %% [markdown]
# DFS_I Barabasi 30 Nodos

# %%
g = Grafo("BarabasiAlbert 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoBarabasiAlbert 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoBarabasiAlbert 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre BarabasiAlbert 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-28
# Arista: N-28-N-20
# Nodo: N-27
# Arista: N-27-N-28
# Nodo: N-5
# Arista: N-5-N-4
# Nodo: N-11
# Arista: N-11-N-13
# Nodo: N-12
# Arista: N-12-N-13
# Nodo: N-8
# Arista: N-8-N-10
# Nodo: N-16
# Arista: N-16-N-13
# Nodo: N-18
# Arista: N-18-N-20
# Nodo: N-13
# Arista: N-13-N-4
# Nodo: N-26
# Arista: N-26-N-29
# Nodo: N-17
# Arista: N-17-N-13
# Nodo: N-6
# Arista: N-6-N-4
# Nodo: N-25
# Arista: N-25-N-20
# Nodo: N-2
# Arista: N-2-N-0
# Nodo: N-9
# Arista: N-9-N-13
# Nodo: N-21
# Arista: N-21-N-20
# Nodo: N-29
# Arista: N-29-N-28
# Nodo: N-7
# Arista: N-7-N-4
# Nodo: N-19
# Arista: N-19-N-20
# Nodo: N-15
# Arista: N-15-N-20
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-22
# Arista: N-22-N-28
# Nodo: N-14
# ...

# %% [markdown]
# DFS_R Barabasi 30 Nodos

# %%
g = Grafo("BarabasiAlbert 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoBarabasiAlbert 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoBarabasiAlbert 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre BarabasiAlbert 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-3
# Nodo: N-28
# Arista: N-28-N-27
# Nodo: N-27
# Arista: N-27-N-26
# Nodo: N-5
# Arista: N-5-N-4
# Nodo: N-11
# Arista: N-11-N-10
# Nodo: N-12
# Arista: N-12-N-11
# Nodo: N-8
# Arista: N-8-N-7
# Nodo: N-21
# Arista: N-21-N-20
# Nodo: N-16
# Arista: N-16-N-15
# Nodo: N-18
# Arista: N-18-N-17
# Nodo: N-29
# Arista: N-29-N-28
# Nodo: N-7
# Arista: N-7-N-6
# Nodo: N-19
# Arista: N-19-N-18
# Nodo: N-13
# Arista: N-13-N-12
# Nodo: N-15
# Arista: N-15-N-14
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-26
# Arista: N-26-N-25
# Nodo: N-22
# Arista: N-22-N-21
# Nodo: N-14
# Arista: N-14-N-13
# Nodo: N-24
# Arista: N-24-N-23
# Nodo: N-17
# Arista: N-17-N-16
# Nodo: N-10
# Arista: N-10-N-9
# Nodo: N-20
# Arista: N-20-N-19
# Nodo: N-6
# ...

# %% [markdown]
# BFS Dorogovtsev 30 Nodos

# %%
g = Grafo("DorogovtsevMendez 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoDorogovtsevMendez 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoDorogovtsevMendez 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre DorogovtsevMendez 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-28
# Arista: N-28-N-1
# Nodo: N-27
# Arista: N-27-N-1
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-5
# Arista: N-5-N-1
# Nodo: N-12
# Arista: N-12-N-1
# Nodo: N-8
# Arista: N-8-N-2
# Nodo: N-16
# Arista: N-16-N-10
# Nodo: N-18
# Arista: N-18-N-10
# Nodo: N-13
# Arista: N-13-N-6
# Nodo: N-26
# Arista: N-26-N-2
# Nodo: N-17
# Arista: N-17-N-1
# Nodo: N-6
# Arista: N-6-N-0
# Nodo: N-25
# Arista: N-25-N-0
# Nodo: N-2
# Arista: N-2-N-0
# Nodo: N-9
# Arista: N-9-N-1
# Nodo: N-21
# Arista: N-21-N-1
# Nodo: N-29
# Arista: N-29-N-7
# Nodo: N-7
# Arista: N-7-N-1
# Nodo: N-19
# Arista: N-19-N-15
# Nodo: N-15
# Arista: N-15-N-10
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-22
# Arista: N-22-N-16
# Nodo: N-14
# ...

# %% [markdown]
# DFS_I Dorogovtsev 30 Nodos

# %%
g = Grafo("DorogovtsevMendez 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoDorogovtsevMendez 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoDorogovtsevMendez 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre DorogovtsevMendez 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-28
# Arista: N-28-N-1
# Nodo: N-27
# Arista: N-27-N-1
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-5
# Arista: N-5-N-2
# Nodo: N-12
# Arista: N-12-N-1
# Nodo: N-8
# Arista: N-8-N-2
# Nodo: N-18
# Arista: N-18-N-14
# Nodo: N-16
# Arista: N-16-N-10
# Nodo: N-13
# Arista: N-13-N-10
# Nodo: N-26
# Arista: N-26-N-2
# Nodo: N-17
# Arista: N-17-N-1
# Nodo: N-6
# Arista: N-6-N-0
# Nodo: N-25
# Arista: N-25-N-0
# Nodo: N-2
# Arista: N-2-N-0
# Nodo: N-9
# Arista: N-9-N-1
# Nodo: N-21
# Arista: N-21-N-1
# Nodo: N-29
# Arista: N-29-N-9
# Nodo: N-7
# Arista: N-7-N-2
# Nodo: N-19
# Arista: N-19-N-16
# Nodo: N-15
# Arista: N-15-N-14
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-22
# Arista: N-22-N-16
# Nodo: N-14
# ...

# %% [markdown]
# DFS_R Dorogovtsev 30 Nodos

# %%
g = Grafo("DorogovtsevMendez 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoDorogovtsevMendez 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoDorogovtsevMendez 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre DorogovtsevMendez 30 nodos NoDir.
# Nodo: N-28
# Arista: N-28-N-9
# Nodo: N-4
# Arista: N-4-N-3
# Nodo: N-27
# Arista: N-27-N-7
# Nodo: N-5
# Arista: N-5-N-2
# Nodo: N-11
# Arista: N-11-N-4
# Nodo: N-12
# Arista: N-12-N-3
# Nodo: N-8
# Arista: N-8-N-5
# Nodo: N-21
# Arista: N-21-N-9
# Nodo: N-18
# Arista: N-18-N-14
# Nodo: N-29
# Arista: N-29-N-9
# Nodo: N-16
# Arista: N-16-N-15
# Nodo: N-7
# Arista: N-7-N-2
# Nodo: N-19
# Arista: N-19-N-16
# Nodo: N-13
# Arista: N-13-N-10
# Nodo: N-15
# Arista: N-15-N-14
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-26
# Arista: N-26-N-5
# Nodo: N-22
# Arista: N-22-N-20
# Nodo: N-14
# Arista: N-14-N-10
# Nodo: N-24
# Arista: N-24-N-14
# Nodo: N-17
# Arista: N-17-N-9
# Nodo: N-10
# Arista: N-10-N-6
# Nodo: N-20
# Arista: N-20-N-19
# Nodo: N-6
# ...

# %% [markdown]
# BFS Erdos 30 Nodos

# %%
g = Grafo("ErdosRenyi 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoErdosRenyi 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoErdosRenyi 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-11
# Nodo: N-28
# Arista: N-28-N-18
# Nodo: N-27
# Arista: N-27-N-17
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-5
# Arista: N-5-N-6
# Nodo: N-12
# Arista: N-12-N-14
# Nodo: N-8
# Arista: N-8-N-26
# Nodo: N-18
# Arista: N-18-N-0
# Nodo: N-16
# Arista: N-16-N-26
# Nodo: N-13
# Arista: N-13-N-0
# Nodo: N-26
# Arista: N-26-N-20
# Nodo: N-17
# Arista: N-17-N-13
# Nodo: N-6
# Arista: N-6-N-11
# Nodo: N-25
# Arista: N-25-N-18
# Nodo: N-2
# Arista: N-2-N-25
# Nodo: N-9
# Arista: N-9-N-20
# Nodo: N-21
# Arista: N-21-N-11
# Nodo: N-29
# Arista: N-29-N-4
# Nodo: N-19
# Arista: N-19-N-20
# Nodo: N-7
# Arista: N-7-N-13
# Nodo: N-15
# Arista: N-15-N-18
# Nodo: N-1
# Arista: N-1-N-22
# Nodo: N-22
# Arista: N-22-N-18
# Nodo: N-14
# ...

# %% [markdown]
# DFS_I Erdos 30 Nodos

# %%
g = Grafo("ErdosRenyi 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoErdosRenyi 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoErdosRenyi 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-23
# Nodo: N-28
# Arista: N-28-N-18
# Nodo: N-27
# Arista: N-27-N-17
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-5
# Arista: N-5-N-25
# Nodo: N-12
# Arista: N-12-N-14
# Nodo: N-8
# Arista: N-8-N-26
# Nodo: N-18
# Arista: N-18-N-0
# Nodo: N-16
# Arista: N-16-N-14
# Nodo: N-13
# Arista: N-13-N-0
# Nodo: N-26
# Arista: N-26-N-20
# Nodo: N-17
# Arista: N-17-N-13
# Nodo: N-6
# Arista: N-6-N-14
# Nodo: N-25
# Arista: N-25-N-14
# Nodo: N-2
# Arista: N-2-N-25
# Nodo: N-9
# Arista: N-9-N-20
# Nodo: N-21
# Arista: N-21-N-18
# Nodo: N-29
# Arista: N-29-N-16
# Nodo: N-7
# Arista: N-7-N-25
# Nodo: N-19
# Arista: N-19-N-20
# Nodo: N-15
# Arista: N-15-N-22
# Nodo: N-1
# Arista: N-1-N-22
# Nodo: N-22
# Arista: N-22-N-20
# Nodo: N-14
# ...

# %% [markdown]
# DFS_R Erdos 30 Nodos

# %%
g = Grafo("ErdosRenyi 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoErdosRenyi 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoErdosRenyi 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-20
# Nodo: N-28
# Arista: N-28-N-21
# Nodo: N-27
# Arista: N-27-N-17
# Nodo: N-11
# Arista: N-11-N-4
# Nodo: N-5
# Arista: N-5-N-6
# Nodo: N-12
# Arista: N-12-N-14
# Nodo: N-8
# Arista: N-8-N-5
# Nodo: N-21
# Arista: N-21-N-18
# Nodo: N-16
# Arista: N-16-N-26
# Nodo: N-18
# Arista: N-18-N-22
# Nodo: N-29
# Arista: N-29-N-19
# Nodo: N-7
# Arista: N-7-N-16
# Nodo: N-19
# Arista: N-19-N-15
# Nodo: N-13
# Arista: N-13-N-7
# Nodo: N-15
# Arista: N-15-N-18
# Nodo: N-1
# Arista: N-1-N-2
# Nodo: N-26
# Arista: N-26-N-8
# Nodo: N-22
# Arista: N-22-N-1
# Nodo: N-14
# Arista: N-14-N-3
# Nodo: N-24
# Arista: N-24-N-10
# Nodo: N-17
# Arista: N-17-N-13
# Nodo: N-10
# Arista: N-10-N-15
# Nodo: N-20
# Arista: N-20-N-0
# Nodo: N-6
# ...

# %% [markdown]
# BFS Geográfico 30 Nodos

# %%
g = Grafo("Geografico 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoGeografico 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoGeografico 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 30 nodos NoDir.
# Nodo: N-0
# Grafo exportado a BFS - Geografico 30 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# DFS_I Geográfico 30 Nodos

# %%
g = Grafo("Geografico 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoGeografico 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoGeografico 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 30 nodos NoDir.
# Grafo exportado a DPS_I - Geografico 30 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# DFS_R Georgráfico 30 Nodos

# %%
g = Grafo("Geografico 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoGeografico 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoGeografico 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 30 nodos NoDir.
# Grafo exportado a DPS_R - Geografico 30 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# BFS Gilbert 30 Nodos

# %%
g = Grafo("Gilbert 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoGilbert 30,0.4NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoGilbert 30,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-28
# Arista: N-28-N-0
# Nodo: N-27
# Arista: N-27-N-5
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-5
# Arista: N-5-N-0
# Nodo: N-12
# Arista: N-12-N-0
# Nodo: N-8
# Arista: N-8-N-0
# Nodo: N-18
# Arista: N-18-N-0
# Nodo: N-16
# Arista: N-16-N-0
# Nodo: N-13
# Arista: N-13-N-4
# Nodo: N-26
# Arista: N-26-N-0
# Nodo: N-17
# Arista: N-17-N-0
# Nodo: N-6
# Arista: N-6-N-24
# Nodo: N-25
# Arista: N-25-N-4
# Nodo: N-2
# Arista: N-2-N-4
# Nodo: N-9
# Arista: N-9-N-11
# Nodo: N-21
# Arista: N-21-N-0
# Nodo: N-29
# Arista: N-29-N-0
# Nodo: N-7
# Arista: N-7-N-0
# Nodo: N-19
# Arista: N-19-N-24
# Nodo: N-15
# Arista: N-15-N-28
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-22
# Arista: N-22-N-28
# Nodo: N-14
# Arista: N-14-N-4
# Nodo: N-24
# ...

# %% [markdown]
# DFS_I Gilbert 30 Nodos

# %%
g = Grafo("Gilbert 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoGilbert 30,0.4NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoGilbert 30,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-28
# Arista: N-28-N-0
# Nodo: N-27
# Arista: N-27-N-26
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-5
# Arista: N-5-N-0
# Nodo: N-12
# Arista: N-12-N-0
# Nodo: N-8
# Arista: N-8-N-0
# Nodo: N-18
# Arista: N-18-N-0
# Nodo: N-16
# Arista: N-16-N-0
# Nodo: N-13
# Arista: N-13-N-28
# Nodo: N-26
# Arista: N-26-N-0
# Nodo: N-17
# Arista: N-17-N-0
# Nodo: N-6
# Arista: N-6-N-19
# Nodo: N-25
# Arista: N-25-N-28
# Nodo: N-2
# Arista: N-2-N-26
# Nodo: N-9
# Arista: N-9-N-29
# Nodo: N-21
# Arista: N-21-N-0
# Nodo: N-29
# Arista: N-29-N-0
# Nodo: N-7
# Arista: N-7-N-0
# Nodo: N-19
# Arista: N-19-N-29
# Nodo: N-15
# Arista: N-15-N-28
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-22
# Arista: N-22-N-28
# Nodo: N-14
# Arista: N-14-N-28
# Nodo: N-24
# ...

# %% [markdown]
# DFS_R Gilbert 30 Nodos

# %%
g = Grafo("Gilbert 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoGilbert 30,0.4NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoGilbert 30,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 30 nodos NoDir.
# Nodo: N-4
# Arista: N-4-N-5
# Nodo: N-28
# Arista: N-28-N-15
# Nodo: N-27
# Arista: N-27-N-1
# Nodo: N-5
# Arista: N-5-N-27
# Nodo: N-11
# Arista: N-11-N-26
# Nodo: N-12
# Arista: N-12-N-13
# Nodo: N-8
# Arista: N-8-N-11
# Nodo: N-21
# Arista: N-21-N-12
# Nodo: N-18
# Arista: N-18-N-14
# Nodo: N-16
# Arista: N-16-N-22
# Nodo: N-29
# Arista: N-29-N-24
# Nodo: N-7
# Arista: N-7-N-10
# Nodo: N-19
# Arista: N-19-N-6
# Nodo: N-13
# Arista: N-13-N-19
# Nodo: N-15
# Arista: N-15-N-18
# Nodo: N-1
# Arista: N-1-N-3
# Nodo: N-26
# Arista: N-26-N-2
# Nodo: N-22
# Arista: N-22-N-20
# Nodo: N-14
# Arista: N-14-N-21
# Nodo: N-24
# Arista: N-24-N-25
# Nodo: N-17
# Arista: N-17-N-29
# Nodo: N-10
# Arista: N-10-N-0
# Nodo: N-20
# Arista: N-20-N-28
# Nodo: N-6
# Arista: N-6-N-9
# ...

# %% [markdown]
# BFS Malla 30 Nodos

# %%
g = Grafo("Malla 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoMalla 10x3 NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoMalla 10x3 NoDir.gv en formato GraphViz a Grafo con nombre Malla 30 nodos NoDir.
# Nodo: N9,2
# Arista: N9,2-N9,1
# Nodo: N4,0
# Arista: N4,0-N3,0
# Nodo: N0,2
# Arista: N0,2-N0,1
# Nodo: N0,0
# Nodo: N9,1
# Arista: N9,1-N9,0
# Nodo: N5,2
# Arista: N5,2-N4,2
# Nodo: N3,1
# Arista: N3,1-N3,0
# Nodo: N7,0
# Arista: N7,0-N6,0
# Nodo: N1,0
# Arista: N1,0-N0,0
# Nodo: N7,1
# Arista: N7,1-N6,1
# Nodo: N0,1
# Arista: N0,1-N0,0
# Nodo: N6,1
# Arista: N6,1-N6,0
# Nodo: N3,2
# Arista: N3,2-N2,2
# Nodo: N8,2
# Arista: N8,2-N7,2
# Nodo: N4,1
# Arista: N4,1-N4,0
# Nodo: N7,2
# Arista: N7,2-N7,1
# Nodo: N5,1
# Arista: N5,1-N4,1
# Nodo: N2,0
# Arista: N2,0-N1,0
# Nodo: N1,1
# Arista: N1,1-N0,1
# Nodo: N6,2
# Arista: N6,2-N6,1
# Nodo: N9,0
# Arista: N9,0-N8,0
# Nodo: N8,0
# Arista: N8,0-N7,0
# Nodo: N4,2
# Arista: N4,2-N4,1
# Nodo: N1,2
# Arista: N1,2-N1,1
# ...

# %% [markdown]
# DFS_I Malla 30 Nodos

# %%
g = Grafo("Malla 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoMalla 10x3 NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoMalla 10x3 NoDir.gv en formato GraphViz a Grafo con nombre Malla 30 nodos NoDir.
# Nodo: N9,2
# Arista: N9,2-N8,2
# Nodo: N4,0
# Arista: N4,0-N5,0
# Nodo: N0,2
# Arista: N0,2-N0,1
# Nodo: N0,0
# Arista: N0,0-N0,1
# Nodo: N9,1
# Arista: N9,1-N9,2
# Nodo: N5,2
# Arista: N5,2-N4,2
# Nodo: N3,1
# Arista: N3,1-N3,2
# Nodo: N7,0
# Arista: N7,0-N8,0
# Nodo: N1,0
# Arista: N1,0-N0,0
# Nodo: N7,1
# Arista: N7,1-N7,2
# Nodo: N0,1
# Arista: N0,1-N0,0
# Nodo: N6,1
# Arista: N6,1-N6,2
# Nodo: N3,2
# Arista: N3,2-N2,2
# Nodo: N8,2
# Arista: N8,2-N7,2
# Nodo: N4,1
# Arista: N4,1-N4,2
# Nodo: N7,2
# Arista: N7,2-N6,2
# Nodo: N5,1
# Arista: N5,1-N5,2
# Nodo: N2,0
# Arista: N2,0-N3,0
# Nodo: N1,1
# Arista: N1,1-N0,1
# Nodo: N6,2
# Arista: N6,2-N5,2
# Nodo: N9,0
# Arista: N9,0-N9,1
# Nodo: N8,0
# Arista: N8,0-N9,0
# Nodo: N4,2
# Arista: N4,2-N3,2
# Nodo: N1,2
# ...

# %% [markdown]
# DFS_R Malla 30 Nodos

# %%
g = Grafo("Malla 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\30 Nodos\\GrafoMalla 10x3 NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\30 Nodos\GrafoMalla 10x3 NoDir.gv en formato GraphViz a Grafo con nombre Malla 30 nodos NoDir.
# Nodo: N1,1
# Arista: N1,1-N2,1
# Nodo: N9,0
# Arista: N9,0-N8,0
# Nodo: N6,2
# Arista: N6,2-N5,2
# Nodo: N9,2
# Arista: N9,2-N8,2
# Nodo: N4,0
# Arista: N4,0-N3,0
# Nodo: N0,2
# Arista: N0,2-N0,1
# Nodo: N8,0
# Arista: N8,0-N7,0
# Nodo: N4,2
# Arista: N4,2-N3,2
# Nodo: N1,2
# Arista: N1,2-N0,2
# Nodo: N9,1
# Arista: N9,1-N9,0
# Nodo: N3,1
# Arista: N3,1-N4,1
# Nodo: N7,0
# Arista: N7,0-N6,0
# Nodo: N5,2
# Arista: N5,2-N4,2
# Nodo: N2,0
# Arista: N2,0-N1,0
# Nodo: N1,0
# Arista: N1,0-N0,0
# Nodo: N7,1
# Arista: N7,1-N8,1
# Nodo: N0,1
# Arista: N0,1-N1,1
# Nodo: N3,0
# Arista: N3,0-N2,0
# Nodo: N6,1
# Arista: N6,1-N7,1
# Nodo: N3,2
# Arista: N3,2-N2,2
# Nodo: N8,2
# Arista: N8,2-N7,2
# Nodo: N2,2
# Arista: N2,2-N1,2
# Nodo: N6,0
# Arista: N6,0-N5,0
# Nodo: N4,1
# ...
