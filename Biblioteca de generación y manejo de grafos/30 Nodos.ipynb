# %%
from GraphPy.Estructura.Grafo import Grafo
from GraphPy.Generadores.GrafoGeografico import grafoGeografico

# %% [markdown]
# MST Barabasi 30 Nodos

# %%
g = Grafo("Barabasi 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\30 Nodos\\GrafoBarabasiAlbert 30-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\30 Nodos\GrafoBarabasiAlbert 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Barabasi 30 nodos NoDir.
# Valor del árbol de expansión mínima: 503.365
# Grafo exportado a Kruskal-D Barabasi 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 503.365
# Grafo exportado a Kruskal-I Barabasi 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 503.365
# Grafo exportado a Prim - Barabasi 30 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Dorogovtsev 30 Nodos

# %%
g = Grafo("Dorogovtsev 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\30 Nodos\\GrafoDorogovtsevMendez 30-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\30 Nodos\GrafoDorogovtsevMendez 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Dorogovtsev 30 nodos NoDir.
# Valor del árbol de expansión mínima: 814.855
# Grafo exportado a Kruskal-D Dorogovtsev 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 814.855
# Grafo exportado a Kruskal-I Dorogovtsev 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 814.855
# Grafo exportado a Prim - Dorogovtsev 30 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Erdos 30 Nodos

# %%
g = Grafo("ErdosRenyi 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\30 Nodos\\GrafoErdosRenyi 30-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\30 Nodos\GrafoErdosRenyi 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 30 nodos NoDir.
# Valor del árbol de expansión mínima: 809.284
# Grafo exportado a Kruskal-D ErdosRenyi 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 809.284
# Grafo exportado a Kruskal-I ErdosRenyi 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 809.284
# Grafo exportado a Prim - ErdosRenyi 30 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Geográfico 30 Nodos

# %%
g = Grafo("Geografico 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\30 Nodos\\GrafoGeografico 30-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\30 Nodos\GrafoGeografico 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 30 nodos NoDir.
# Valor del árbol de expansión mínima: 89.61
# Grafo exportado a Kruskal-D Geografico 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 89.61
# Grafo exportado a Kruskal-I Geografico 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 144.471
# Grafo exportado a Prim - Geografico 30 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Gilbert 30 Nodos

# %%
g = Grafo("Gilbert 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\30 Nodos\\GrafoGilbert 30,0.4NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\30 Nodos\GrafoGilbert 30,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 30 nodos NoDir.
# Valor del árbol de expansión mínima: 226.489
# Grafo exportado a Kruskal-D Gilbert 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 226.489
# Grafo exportado a Kruskal-I Gilbert 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 226.489
# Grafo exportado a Prim - Gilbert 30 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# Dijkstra Malla 30 Nodos

# %%
g = Grafo("Malla 30 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\30 Nodos\\GrafoMalla 10x3 NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\30 Nodos\GrafoMalla 10x3 NoDir.gv en formato GraphViz a Grafo con nombre Malla 30 nodos NoDir.
# Valor del árbol de expansión mínima: 1024.064
# Grafo exportado a Kruskal-D Malla 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 1024.064
# Grafo exportado a Kruskal-I Malla 30 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 1024.064
# Grafo exportado a Prim - Malla 30 nodos NoDir.gv en formato GraphViz.
