# %%
from GraphPy.Estructura.Grafo import Grafo

# %%
g = Grafo("Gilbert 500")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Proyecto 2 - Algoritmos BFS y DFS\\30 nodos\\GrafoGilbert 30,0.4NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Proyecto 2 - Algoritmos BFS y DFS\30 nodos\GrafoGilbert 30,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 500.
# Nodo: N-13
# Arista: N-13-N-17
# Nodo: N-5
# Arista: N-5-N-0
# Nodo: N-7
# Arista: N-7-N-0
# Nodo: N-8
# Arista: N-8-N-0
# Nodo: N-2
# Arista: N-2-N-17
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-16
# Arista: N-16-N-0
# Nodo: N-23
# Arista: N-23-N-0
# Nodo: N-21
# Arista: N-21-N-0
# Nodo: N-25
# Arista: N-25-N-12
# Nodo: N-0
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-12
# Arista: N-12-N-0
# Nodo: N-3
# Arista: N-3-N-21
# Nodo: N-24
# Arista: N-24-N-0
# Nodo: N-6
# Arista: N-6-N-23
# Nodo: N-14
# Arista: N-14-N-23
# Nodo: N-10
# Arista: N-10-N-0
# Nodo: N-28
# Arista: N-28-N-0
# Nodo: N-9
# Arista: N-9-N-23
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-15
# Arista: N-15-N-21
# Nodo: N-18
# Arista: N-18-N-0
# Nodo: N-17
# Arista: N-17-N-0
# Nodo: N-22
# Arista: N-22-N-17
# Nodo: N-19
# Arista: N-19-N-17
# ...

# %%
g = Grafo("Barabasi 500")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Proyecto 2 - Algoritmos BFS y DFS\\30 nodos\\GrafoBarabasiAlbert 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Proyecto 2 - Algoritmos BFS y DFS\30 nodos\GrafoBarabasiAlbert 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Barabasi 500.
# Nodo: N-13
# Arista: N-13-N-4
# Nodo: N-5
# Arista: N-5-N-4
# Nodo: N-7
# Arista: N-7-N-4
# Nodo: N-8
# Arista: N-8-N-5
# Nodo: N-2
# Arista: N-2-N-0
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-16
# Arista: N-16-N-13
# Nodo: N-23
# Arista: N-23-N-17
# Nodo: N-21
# Arista: N-21-N-11
# Nodo: N-25
# Arista: N-25-N-20
# Nodo: N-0
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-3
# Arista: N-3-N-0
# Nodo: N-12
# Arista: N-12-N-13
# Nodo: N-24
# Arista: N-24-N-21
# Nodo: N-6
# Arista: N-6-N-4
# Nodo: N-14
# Arista: N-14-N-1
# Nodo: N-10
# Arista: N-10-N-13
# Nodo: N-28
# Arista: N-28-N-20
# Nodo: N-9
# Arista: N-9-N-13
# Nodo: N-11
# Arista: N-11-N-3
# Nodo: N-15
# Arista: N-15-N-14
# Nodo: N-18
# Arista: N-18-N-14
# Nodo: N-17
# Arista: N-17-N-13
# Nodo: N-22
# Arista: N-22-N-21
# Nodo: N-19
# ...

# %%
g = Grafo("Erdos 500")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Proyecto 2 - Algoritmos BFS y DFS\\30 nodos\\GrafoErdosRenyi 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Proyecto 2 - Algoritmos BFS y DFS\30 nodos\GrafoErdosRenyi 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Erdos 500.
# Nodo: N-13
# Arista: N-13-N-0
# Nodo: N-5
# Arista: N-5-N-22
# Nodo: N-7
# Arista: N-7-N-13
# Nodo: N-8
# Arista: N-8-N-26
# Nodo: N-2
# Arista: N-2-N-25
# Nodo: N-4
# Arista: N-4-N-23
# Nodo: N-16
# Arista: N-16-N-14
# Nodo: N-23
# Arista: N-23-N-0
# Nodo: N-25
# Arista: N-25-N-20
# Nodo: N-21
# Arista: N-21-N-11
# Nodo: N-0
# Nodo: N-1
# Arista: N-1-N-22
# Nodo: N-3
# Arista: N-3-N-22
# Nodo: N-12
# Arista: N-12-N-14
# Nodo: N-24
# Arista: N-24-N-22
# Nodo: N-6
# Arista: N-6-N-11
# Nodo: N-14
# Arista: N-14-N-23
# Nodo: N-10
# Arista: N-10-N-15
# Nodo: N-28
# Arista: N-28-N-18
# Nodo: N-9
# Arista: N-9-N-20
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-15
# Arista: N-15-N-18
# Nodo: N-18
# Arista: N-18-N-0
# Nodo: N-17
# Arista: N-17-N-13
# Nodo: N-22
# Arista: N-22-N-20
# Nodo: N-19
# ...

# %%
g = Grafo("Erdos 500")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Proyecto 2 - Algoritmos BFS y DFS\\30 nodos\\GrafoErdosRenyi 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Proyecto 2 - Algoritmos BFS y DFS\30 nodos\GrafoErdosRenyi 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Erdos 500.
# Nodo: N-13
# Arista: N-13-N-0
# Nodo: N-5
# Arista: N-5-N-25
# Nodo: N-7
# Arista: N-7-N-25
# Nodo: N-8
# Arista: N-8-N-26
# Nodo: N-2
# Arista: N-2-N-25
# Nodo: N-4
# Arista: N-4-N-23
# Nodo: N-16
# Arista: N-16-N-14
# Nodo: N-23
# Arista: N-23-N-0
# Nodo: N-25
# Arista: N-25-N-14
# Nodo: N-21
# Arista: N-21-N-18
# Nodo: N-0
# Arista: N-0-N-23
# Nodo: N-3
# Arista: N-3-N-14
# Nodo: N-12
# Arista: N-12-N-14
# Nodo: N-1
# Arista: N-1-N-22
# Nodo: N-24
# Arista: N-24-N-22
# Nodo: N-6
# Arista: N-6-N-14
# Nodo: N-14
# Arista: N-14-N-23
# Nodo: N-10
# Arista: N-10-N-24
# Nodo: N-28
# Arista: N-28-N-18
# Nodo: N-9
# Arista: N-9-N-20
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-15
# Arista: N-15-N-22
# Nodo: N-18
# Arista: N-18-N-0
# Nodo: N-17
# Arista: N-17-N-13
# Nodo: N-22
# Arista: N-22-N-20
# ...

# %%
g = Grafo("Erdos 500")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Proyecto 2 - Algoritmos BFS y DFS\\30 nodos\\GrafoErdosRenyi 30-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Proyecto 2 - Algoritmos BFS y DFS\30 nodos\GrafoErdosRenyi 30-nodos NoDir.gv en formato GraphViz a Grafo con nombre Erdos 500.
# Nodo: N-13
# Arista: N-13-N-7
# Nodo: N-14
# Arista: N-14-N-3
# Nodo: N-5
# Arista: N-5-N-6
# Nodo: N-8
# Arista: N-8-N-5
# Nodo: N-7
# Arista: N-7-N-16
# Nodo: N-10
# Arista: N-10-N-15
# Nodo: N-28
# Arista: N-28-N-21
# Nodo: N-2
# Arista: N-2-N-12
# Nodo: N-11
# Arista: N-11-N-4
# Nodo: N-9
# Arista: N-9-N-3
# Nodo: N-4
# Arista: N-4-N-20
# Nodo: N-15
# Arista: N-15-N-18
# Nodo: N-16
# Arista: N-16-N-26
# Nodo: N-18
# Arista: N-18-N-22
# Nodo: N-23
# Arista: N-23-N-14
# Nodo: N-22
# Arista: N-22-N-1
# Nodo: N-17
# Arista: N-17-N-13
# Nodo: N-21
# Arista: N-21-N-18
# Nodo: N-25
# Arista: N-25-N-18
# Nodo: N-12
# Arista: N-12-N-14
# Nodo: N-3
# Arista: N-3-N-7
# Nodo: N-1
# Arista: N-1-N-2
# Nodo: N-19
# Arista: N-19-N-15
# Nodo: N-24
# Arista: N-24-N-10
# Nodo: N-6
# Arista: N-6-N-11
# Nodo: N-29
# ...

# %%
g = Grafo("Dorogovtsev 500")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Proyecto 2 - Algoritmos BFS y DFS\\30 nodos\\No Subir\\ErdosRenyi 30-nodos Dir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Proyecto 2 - Algoritmos BFS y DFS\30 nodos\GrafoDorogovtsevMendez 30-nodos Dir.gv en formato GraphViz a Grafo con nombre Dorogovtsev 500.
# Nodo: N-1
# Arista: N-1-N-0
# Nodo: N-2
# Arista: N-2-N-0
# Nodo: N-0
# Arista: N-0-N-2
# Grafo exportado a DPS_I - Dorogovtsev 500.gv en formato GraphViz.

# %%
g = Grafo("Renyi 500")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Proyecto 2 - Algoritmos BFS y DFS\\30 nodos\\No Subir\\ErdosRenyi 30-nodos Dir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Proyecto 2 - Algoritmos BFS y DFS\30 nodos\No Subir\ErdosRenyi 30-nodos Dir.gv en formato GraphViz a Grafo con nombre Renyi 500.
# Nodo: N-13
# Arista: N-13-N-3
# Nodo: N-5
# Arista: N-5-N-13
# Nodo: N-8
# Arista: N-8-N-21
# Nodo: N-7
# Arista: N-7-N-18
# Nodo: N-2
# Arista: N-2-N-13
# Nodo: N-4
# Arista: N-4-N-18
# Nodo: N-23
# Arista: N-23-N-5
# Nodo: N-25
# Arista: N-25-N-3
# Nodo: N-21
# Arista: N-21-N-13
# Nodo: N-0
# Nodo: N-3
# Arista: N-3-N-24
# Nodo: N-1
# Arista: N-1-N-8
# Nodo: N-24
# Arista: N-24-N-0
# Nodo: N-6
# Arista: N-6-N-21
# Nodo: N-10
# Arista: N-10-N-23
# Nodo: N-18
# Arista: N-18-N-23
# Nodo: N-17
# Arista: N-17-N-24
# Nodo: N-19
# Arista: N-19-N-1
# Nodo: N-29
# Arista: N-29-N-21
# Nodo: N-20
# Arista: N-20-N-3
# Nodo: N-26
# Arista: N-26-N-6
# Grafo exportado a BFS - Renyi 500.gv en formato GraphViz.
