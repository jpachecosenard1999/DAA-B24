# %%
from GraphPy.Estructura.Grafo import Grafo
from GraphPy.Generadores.GrafoGeografico import grafoGeografico
from GraphPy.Generadores.GrafoErdosRenyi import grafoErdosRenyi

# %% [markdown]
# Dijkstra Barabasi 100 Nodos

# %%
g = Grafo("BarabasiAlbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\100 Nodos\\GrafoBarabasiAlbert 100-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()

# %% [markdown]
# Dijkstra Dorogovtsev 100 Nodos

# %%
g = Grafo("Dorogovtsev 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\100 Nodos\\GrafoDorogovtsevMendez 100-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()

# %% [markdown]
# Dijkstra Erdos 100 Nodos

# %%
g = grafoErdosRenyi(100, 1000, dirigido = True)

g.MostrarGrafo()

g.Guardar()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()

# %% [markdown]
# Dijkstra Geográfico 100 Nodos

# %%
g = grafoGeografico(100, .99, dirigido = True)

g.MostrarGrafo()

g.Guardar()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()

# %% [markdown]
# Dijkstra Gilbert 100 Nodos

# %%
g = Grafo("Gilbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\100 Nodos\\GrafoGilbert 100,0.4NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()

# %% [markdown]
# Dijkstra Malla 100 Nodos

# %%
g = Grafo("Malla 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos Dijkstra\\100 Nodos\\GrafoMalla 10x10 NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

nodo = g.nodos[0]

a = g.Dijkstra(nodo)

a.MostrarGrafo()
