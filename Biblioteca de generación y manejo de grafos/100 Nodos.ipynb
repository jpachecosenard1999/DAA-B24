# %%
from GraphPy.Estructura.Grafo import Grafo
from GraphPy.Generadores.GrafoGeografico import grafoGeografico
import cv2
import sys

sys.setrecursionlimit(50000)
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Hiperparámetros

# %%
# Configuración de Pygame
ANCHO, ALTO = 1600, 1200
BLANCO = (255, 255, 255)
NEGRO = (0, 0, 0)
AZUL = (0, 0, 255)

# %% [markdown]
# Barabasi 100 Nodos

# %%
g = Grafo("Barabasi 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\100 Nodos\\GrafoBarabasiAlbert 100-nodos NoDir.gv")


g.FruchtermanReingold(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)

g.BarnesHut(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\100 Nodos\GrafoBarabasiAlbert 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre Barabasi 100 nodos NoDir.
# Visualización Fruchterman-Reingold guardada como: Barabasi 100 nodos NoDir_FR.png
# Visualización Barnes-Hut guardada como: Barabasi 100 nodos NoDir_BH.png

# %% [markdown]
# Dorogovtsev 100 Nodos

# %%
g = Grafo("Dorogovtsev 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\100 Nodos\\GrafoDorogovtsevMendez 100-nodos NoDir.gv")

g.FruchtermanReingold(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)

g.BarnesHut(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\100 Nodos\GrafoDorogovtsevMendez 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre Dorogovtsev 100 nodos NoDir.
# Visualización Fruchterman-Reingold guardada como: Dorogovtsev 100 nodos NoDir_FR.png
# Visualización Barnes-Hut guardada como: Dorogovtsev 100 nodos NoDir_BH.png

# %% [markdown]
# Erdos 100 Nodos

# %%
g = Grafo("ErdosRenyi 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\100 Nodos\\GrafoErdosRenyi 100-nodos NoDir.gv")

g.FruchtermanReingold(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)

g.BarnesHut(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\100 Nodos\GrafoErdosRenyi 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 100 nodos NoDir.
# Visualización Fruchterman-Reingold guardada como: ErdosRenyi 100 nodos NoDir_FR.png
# Visualización Barnes-Hut guardada como: ErdosRenyi 100 nodos NoDir_BH.png

# %% [markdown]
# Geográfico 100 Nodos

# %%
g = Grafo("Geografico 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\100 Nodos\\GrafoGeografico 100-nodos NoDir.gv")

g.FruchtermanReingold(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)

g.BarnesHut(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\100 Nodos\GrafoGeografico 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 100 nodos NoDir.
# Visualización Fruchterman-Reingold guardada como: Geografico 100 nodos NoDir_FR.png
# Visualización Barnes-Hut guardada como: Geografico 100 nodos NoDir_BH.png

# %% [markdown]
# Gilbert 100 Nodos

# %%
g = Grafo("Gilbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\100 Nodos\\GrafoGilbert 100,0.4NoDir.gv")

g.FruchtermanReingold(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)

g.BarnesHut(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\100 Nodos\GrafoGilbert 100,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 100 nodos NoDir.
# Visualización Fruchterman-Reingold guardada como: Gilbert 100 nodos NoDir_FR.png
# Visualización Barnes-Hut guardada como: Gilbert 100 nodos NoDir_BH.png

# %% [markdown]
# Malla 100 Nodos

# %%
g = Grafo("Malla 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos GV\\100 Nodos\\GrafoMalla 10x10 NoDir.gv")

g.FruchtermanReingold(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)

g.BarnesHut(ANCHO, ALTO, BLANCO, NEGRO, AZUL, iteraciones= 1000)
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos GV\100 Nodos\GrafoMalla 10x10 NoDir.gv en formato GraphViz a Grafo con nombre Malla 100 nodos NoDir.
# Visualización Fruchterman-Reingold guardada como: Malla 100 nodos NoDir_FR.png
# Visualización Barnes-Hut guardada como: Malla 100 nodos NoDir_BH.png
