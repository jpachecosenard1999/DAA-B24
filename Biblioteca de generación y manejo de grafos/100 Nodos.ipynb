# %%
from GraphPy.Estructura.Grafo import Grafo
from GraphPy.Generadores.GrafoGeografico import grafoGeografico

# %% [markdown]
# MST Barabasi 100 Nodos

# %%
g = Grafo("Barabasi 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\100 Nodos\\GrafoBarabasiAlbert 100-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\100 Nodos\GrafoBarabasiAlbert 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre Barabasi 100 nodos NoDir.
# Valor del árbol de expansión mínima: 1265.672
# Grafo exportado a Kruskal-D Barabasi 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 1265.672
# Grafo exportado a Kruskal-I Barabasi 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 1265.672
# Grafo exportado a Prim - Barabasi 100 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Dorogovtsev 100 Nodos

# %%
g = Grafo("Dorogovtsev 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\100 Nodos\\GrafoDorogovtsevMendez 100-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\100 Nodos\GrafoDorogovtsevMendez 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre Dorogovtsev 100 nodos NoDir.
# Valor del árbol de expansión mínima: 3002.592
# Grafo exportado a Kruskal-D Dorogovtsev 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 3002.592
# Grafo exportado a Kruskal-I Dorogovtsev 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 3002.592
# Grafo exportado a Prim - Dorogovtsev 100 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Erdos 100 Nodos

# %%
g = Grafo("ErdosRenyi 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\100 Nodos\\GrafoErdosRenyi 100-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\100 Nodos\GrafoErdosRenyi 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 100 nodos NoDir.
# Valor del árbol de expansión mínima: 571.747
# Grafo exportado a Kruskal-D ErdosRenyi 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 571.747
# Grafo exportado a Kruskal-I ErdosRenyi 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 571.747
# Grafo exportado a Prim - ErdosRenyi 100 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Geográfico 100 Nodos

# %%
g = Grafo("Geografico 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\100 Nodos\\GrafoGeografico 100-nodos NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\100 Nodos\GrafoGeografico 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 100 nodos NoDir.
# Valor del árbol de expansión mínima: 73.974
# Grafo exportado a Kruskal-D Geografico 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 73.974
# Grafo exportado a Kruskal-I Geografico 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 142.956
# Grafo exportado a Prim - Geografico 100 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Gilbert 100 Nodos

# %%
g = Grafo("Gilbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\100 Nodos\\GrafoGilbert 100,0.4NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\100 Nodos\GrafoGilbert 100,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 100 nodos NoDir.
# Valor del árbol de expansión mínima: 175.319
# Grafo exportado a Kruskal-D Gilbert 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 175.319
# Grafo exportado a Kruskal-I Gilbert 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 175.319
# Grafo exportado a Prim - Gilbert 100 nodos NoDir.gv en formato GraphViz.

# %% [markdown]
# MST Malla 100 Nodos

# %%
g = Grafo("Malla 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Árboles de expansión mínima\\100 Nodos\\GrafoMalla 10x10 NoDir.gv")

# g.MostrarGrafo()

g.AsignarPeso()

a = g.KruskalD()

# a.MostrarGrafo()

b = g.KruskalI()

# b.MostrarGrafo()

c = g.Prim(g.nodos[0])

# c.MostrarGrafo()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Árboles de expansión mínima\100 Nodos\GrafoMalla 10x10 NoDir.gv en formato GraphViz a Grafo con nombre Malla 100 nodos NoDir.
# Valor del árbol de expansión mínima: 3414.009
# Grafo exportado a Kruskal-D Malla 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 3414.009
# Grafo exportado a Kruskal-I Malla 100 nodos NoDir.gv en formato GraphViz.
# Valor del árbol de expansión mínima: 3414.009
# Grafo exportado a Prim - Malla 100 nodos NoDir.gv en formato GraphViz.
