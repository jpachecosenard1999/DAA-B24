# %%
from GraphPy.Estructura.Grafo import Grafo

# %% [markdown]
# BFS Barabasi 100 Nodos

# %%
g = Grafo("BarabasiAlbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoBarabasiAlbert 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoBarabasiAlbert 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre BarabasiAlbert 100 nodos NoDir.
# Nodo: N-88
# Arista: N-88-N-74
# Nodo: N-42
# Arista: N-42-N-38
# Nodo: N-13
# Arista: N-13-N-6
# Nodo: N-81
# Arista: N-81-N-77
# Nodo: N-11
# Arista: N-11-N-10
# Nodo: N-4
# Arista: N-4-N-3
# Nodo: N-25
# Arista: N-25-N-22
# Nodo: N-68
# Arista: N-68-N-64
# Nodo: N-39
# Arista: N-39-N-35
# Nodo: N-34
# Arista: N-34-N-33
# Nodo: N-32
# Arista: N-32-N-33
# Nodo: N-10
# Arista: N-10-N-5
# Nodo: N-23
# Arista: N-23-N-16
# Nodo: N-61
# Arista: N-61-N-54
# Nodo: N-84
# Arista: N-84-N-75
# Nodo: N-9
# Arista: N-9-N-10
# Nodo: N-12
# Arista: N-12-N-10
# Nodo: N-86
# Arista: N-86-N-84
# Nodo: N-63
# Arista: N-63-N-59
# Nodo: N-77
# Arista: N-77-N-61
# Nodo: N-62
# Arista: N-62-N-54
# Nodo: N-98
# Arista: N-98-N-96
# Nodo: N-35
# Arista: N-35-N-28
# ...

# %% [markdown]
# DFS_I Barabasi 100 Nodos

# %%
g = Grafo("BarabasiAlbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoBarabasiAlbert 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoBarabasiAlbert 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre BarabasiAlbert 100 nodos NoDir.
# Nodo: N-88
# Arista: N-88-N-84
# Nodo: N-42
# Arista: N-42-N-38
# Nodo: N-13
# Arista: N-13-N-16
# Nodo: N-81
# Arista: N-81-N-88
# Nodo: N-11
# Arista: N-11-N-10
# Nodo: N-4
# Arista: N-4-N-5
# Nodo: N-25
# Arista: N-25-N-28
# Nodo: N-68
# Arista: N-68-N-83
# Nodo: N-39
# Arista: N-39-N-38
# Nodo: N-34
# Arista: N-34-N-38
# Nodo: N-32
# Arista: N-32-N-38
# Nodo: N-10
# Arista: N-10-N-5
# Nodo: N-23
# Arista: N-23-N-33
# Nodo: N-61
# Arista: N-61-N-54
# Nodo: N-84
# Arista: N-84-N-75
# Nodo: N-9
# Arista: N-9-N-10
# Nodo: N-12
# Arista: N-12-N-10
# Nodo: N-86
# Arista: N-86-N-84
# Nodo: N-63
# Arista: N-63-N-62
# Nodo: N-77
# Arista: N-77-N-75
# Nodo: N-62
# Arista: N-62-N-54
# Nodo: N-98
# Arista: N-98-N-97
# Nodo: N-35
# Arista: N-35-N-28
# ...

# %% [markdown]
# DFS_R Barabasi 100 Nodos

# %%
g = Grafo("BarabasiAlbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoBarabasiAlbert 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoBarabasiAlbert 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre BarabasiAlbert 100 nodos NoDir.
# Nodo: N-74
# Arista: N-74-N-73
# Nodo: N-42
# Arista: N-42-N-41
# Nodo: N-73
# Arista: N-73-N-72
# Nodo: N-88
# Arista: N-88-N-87
# Nodo: N-36
# Arista: N-36-N-35
# Nodo: N-13
# Arista: N-13-N-12
# Nodo: N-54
# Arista: N-54-N-53
# Nodo: N-81
# Arista: N-81-N-80
# Nodo: N-11
# Arista: N-11-N-10
# Nodo: N-4
# Arista: N-4-N-3
# Nodo: N-55
# Arista: N-55-N-54
# Nodo: N-25
# Arista: N-25-N-24
# Nodo: N-68
# Arista: N-68-N-67
# Nodo: N-51
# Arista: N-51-N-50
# Nodo: N-91
# Arista: N-91-N-90
# Nodo: N-45
# Arista: N-45-N-44
# Nodo: N-39
# Arista: N-39-N-38
# Nodo: N-34
# Arista: N-34-N-33
# Nodo: N-52
# Arista: N-52-N-51
# Nodo: N-97
# Arista: N-97-N-96
# Nodo: N-60
# Arista: N-60-N-59
# Nodo: N-32
# Arista: N-32-N-31
# Nodo: N-8
# Arista: N-8-N-7
# ...

# %% [markdown]
# BFS Dorogovtsev 100 Nodos

# %%
g = Grafo("DorogovtsevMendez 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoDorogovtsevMendez 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoDorogovtsevMendez 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre DorogovtsevMendez 100 nodos NoDir.
# Nodo: N-88
# Arista: N-88-N-82
# Nodo: N-42
# Arista: N-42-N-9
# Nodo: N-13
# Arista: N-13-N-3
# Nodo: N-81
# Arista: N-81-N-0
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-25
# Arista: N-25-N-13
# Nodo: N-68
# Arista: N-68-N-1
# Nodo: N-39
# Arista: N-39-N-13
# Nodo: N-34
# Arista: N-34-N-2
# Nodo: N-32
# Arista: N-32-N-16
# Nodo: N-10
# Arista: N-10-N-3
# Nodo: N-23
# Arista: N-23-N-0
# Nodo: N-61
# Arista: N-61-N-54
# Nodo: N-84
# Arista: N-84-N-2
# Nodo: N-9
# Arista: N-9-N-3
# Nodo: N-12
# Arista: N-12-N-3
# Nodo: N-86
# Arista: N-86-N-41
# Nodo: N-63
# Arista: N-63-N-51
# Nodo: N-77
# Arista: N-77-N-0
# Nodo: N-62
# Arista: N-62-N-13
# Nodo: N-98
# Arista: N-98-N-9
# Nodo: N-35
# Arista: N-35-N-2
# ...

# %% [markdown]
# DFS_I Dorogovtsev 100 Nodos

# %%
g = Grafo("DorogovtsevMendez 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoDorogovtsevMendez 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoDorogovtsevMendez 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre DorogovtsevMendez 100 nodos NoDir.
# Nodo: N-88
# Arista: N-88-N-82
# Nodo: N-42
# Arista: N-42-N-9
# Nodo: N-13
# Arista: N-13-N-3
# Nodo: N-81
# Arista: N-81-N-0
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-4
# Arista: N-4-N-0
# Nodo: N-25
# Arista: N-25-N-9
# Nodo: N-68
# Arista: N-68-N-1
# Nodo: N-39
# Arista: N-39-N-9
# Nodo: N-34
# Arista: N-34-N-2
# Nodo: N-32
# Arista: N-32-N-8
# Nodo: N-10
# Arista: N-10-N-3
# Nodo: N-23
# Arista: N-23-N-0
# Nodo: N-61
# Arista: N-61-N-54
# Nodo: N-84
# Arista: N-84-N-2
# Nodo: N-9
# Arista: N-9-N-5
# Nodo: N-12
# Arista: N-12-N-3
# Nodo: N-86
# Arista: N-86-N-60
# Nodo: N-63
# Arista: N-63-N-51
# Nodo: N-77
# Arista: N-77-N-0
# Nodo: N-62
# Arista: N-62-N-18
# Nodo: N-98
# Arista: N-98-N-9
# Nodo: N-35
# Arista: N-35-N-2
# ...

# %% [markdown]
# DFS_R Dorogovtsev 100 Nodos

# %%
g = Grafo("DorogovtsevMendez 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoDorogovtsevMendez 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoDorogovtsevMendez 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre DorogovtsevMendez 100 nodos NoDir.
# Nodo: N-74
# Arista: N-74-N-14
# Nodo: N-73
# Arista: N-73-N-60
# Nodo: N-88
# Arista: N-88-N-82
# Nodo: N-42
# Arista: N-42-N-18
# Nodo: N-36
# Arista: N-36-N-20
# Nodo: N-54
# Arista: N-54-N-8
# Nodo: N-13
# Arista: N-13-N-9
# Nodo: N-81
# Arista: N-81-N-74
# Nodo: N-11
# Arista: N-11-N-1
# Nodo: N-4
# Arista: N-4-N-2
# Nodo: N-55
# Arista: N-55-N-51
# Nodo: N-25
# Arista: N-25-N-13
# Nodo: N-68
# Arista: N-68-N-6
# Nodo: N-51
# Arista: N-51-N-28
# Nodo: N-91
# Arista: N-91-N-82
# Nodo: N-45
# Arista: N-45-N-7
# Nodo: N-39
# Arista: N-39-N-13
# Nodo: N-34
# Arista: N-34-N-8
# Nodo: N-52
# Arista: N-52-N-3
# Nodo: N-97
# Arista: N-97-N-6
# Nodo: N-60
# Arista: N-60-N-41
# Nodo: N-32
# Arista: N-32-N-16
# Nodo: N-8
# Arista: N-8-N-2
# ...

# %% [markdown]
# BFS Erdos 100 Nodos

# %%
g = Grafo("ErdosRenyi 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoErdosRenyi 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoErdosRenyi 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 100 nodos NoDir.
# Nodo: N-88
# Arista: N-88-N-66
# Nodo: N-42
# Arista: N-42-N-47
# Nodo: N-13
# Arista: N-13-N-96
# Nodo: N-81
# Arista: N-81-N-98
# Nodo: N-11
# Arista: N-11-N-36
# Nodo: N-4
# Arista: N-4-N-37
# Nodo: N-25
# Arista: N-25-N-20
# Nodo: N-68
# Arista: N-68-N-36
# Nodo: N-34
# Arista: N-34-N-37
# Nodo: N-32
# Arista: N-32-N-4
# Nodo: N-10
# Arista: N-10-N-86
# Nodo: N-23
# Arista: N-23-N-48
# Nodo: N-61
# Arista: N-61-N-67
# Nodo: N-84
# Arista: N-84-N-80
# Nodo: N-9
# Arista: N-9-N-77
# Nodo: N-12
# Arista: N-12-N-53
# Nodo: N-86
# Arista: N-86-N-37
# Nodo: N-63
# Arista: N-63-N-17
# Nodo: N-77
# Arista: N-77-N-86
# Nodo: N-62
# Arista: N-62-N-66
# Nodo: N-98
# Arista: N-98-N-37
# Nodo: N-70
# Arista: N-70-N-57
# Nodo: N-28
# Arista: N-28-N-72
# ...

# %% [markdown]
# DFS_I Erdos 100 Nodos

# %%
g = Grafo("ErdosRenyi 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoErdosRenyi 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoErdosRenyi 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 100 nodos NoDir.
# Nodo: N-88
# Arista: N-88-N-96
# Nodo: N-42
# Arista: N-42-N-96
# Nodo: N-13
# Arista: N-13-N-83
# Nodo: N-81
# Arista: N-81-N-98
# Nodo: N-11
# Arista: N-11-N-56
# Nodo: N-4
# Arista: N-4-N-37
# Nodo: N-25
# Arista: N-25-N-65
# Nodo: N-68
# Arista: N-68-N-36
# Nodo: N-34
# Arista: N-34-N-37
# Nodo: N-32
# Arista: N-32-N-96
# Nodo: N-10
# Arista: N-10-N-97
# Nodo: N-23
# Arista: N-23-N-48
# Nodo: N-61
# Arista: N-61-N-49
# Nodo: N-84
# Arista: N-84-N-71
# Nodo: N-9
# Arista: N-9-N-45
# Nodo: N-12
# Arista: N-12-N-90
# Nodo: N-86
# Arista: N-86-N-10
# Nodo: N-63
# Arista: N-63-N-95
# Nodo: N-77
# Arista: N-77-N-75
# Nodo: N-62
# Arista: N-62-N-16
# Nodo: N-98
# Arista: N-98-N-37
# Nodo: N-70
# Arista: N-70-N-57
# Nodo: N-35
# Arista: N-35-N-47
# ...

# %% [markdown]
# DFS_R Erdos 100 Nodos

# %%
g = Grafo("ErdosRenyi 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoErdosRenyi 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoErdosRenyi 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre ErdosRenyi 100 nodos NoDir.
# Nodo: N-88
# Arista: N-88-N-54
# Nodo: N-42
# Arista: N-42-N-47
# Nodo: N-73
# Arista: N-73-N-57
# Nodo: N-74
# Arista: N-74-N-56
# Nodo: N-36
# Arista: N-36-N-86
# Nodo: N-13
# Arista: N-13-N-67
# Nodo: N-54
# Arista: N-54-N-18
# Nodo: N-81
# Arista: N-81-N-20
# Nodo: N-11
# Arista: N-11-N-36
# Nodo: N-4
# Arista: N-4-N-37
# Nodo: N-55
# Arista: N-55-N-8
# Nodo: N-25
# Arista: N-25-N-65
# Nodo: N-68
# Arista: N-68-N-36
# Nodo: N-51
# Arista: N-51-N-16
# Nodo: N-91
# Arista: N-91-N-44
# Nodo: N-45
# Arista: N-45-N-7
# Nodo: N-52
# Arista: N-52-N-10
# Nodo: N-34
# Arista: N-34-N-37
# Nodo: N-97
# Arista: N-97-N-57
# Nodo: N-60
# Arista: N-60-N-21
# Nodo: N-32
# Arista: N-32-N-4
# Nodo: N-8
# Arista: N-8-N-31
# Nodo: N-65
# Arista: N-65-N-72
# ...

# %% [markdown]
# BFS Geográfico 100 Nodos

# %%
g = Grafo("Geografico 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoGeografico 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoGeografico 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 100 nodos NoDir.
# Nodo: N-74
# Arista: N-74-N-49
# Nodo: N-73
# Arista: N-73-N-24
# Nodo: N-3
# Arista: N-3-N-7
# Nodo: N-36
# Arista: N-36-N-97
# Nodo: N-54
# Arista: N-54-N-0
# Nodo: N-37
# Arista: N-37-N-49
# Nodo: N-96
# Arista: N-96-N-63
# Nodo: N-81
# Arista: N-81-N-44
# Nodo: N-0
# Nodo: N-67
# Arista: N-67-N-17
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-91
# Arista: N-91-N-18
# Nodo: N-34
# Arista: N-34-N-40
# Nodo: N-97
# Arista: N-97-N-28
# Nodo: N-49
# Arista: N-49-N-93
# Nodo: N-38
# Arista: N-38-N-85
# Nodo: N-24
# Arista: N-24-N-11
# Nodo: N-85
# Arista: N-85-N-49
# Nodo: N-44
# Arista: N-44-N-74
# Nodo: N-75
# Arista: N-75-N-7
# Nodo: N-95
# Arista: N-95-N-74
# Nodo: N-23
# Arista: N-23-N-0
# Nodo: N-93
# Arista: N-93-N-24
# Nodo: N-9
# Arista: N-9-N-0
# ...

# %% [markdown]
# DFS_I Geográfico 100 Nodos

# %%
g = Grafo("Geografico 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoGeografico 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoGeografico 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 100 nodos NoDir.
# Nodo: N-74
# Arista: N-74-N-49
# Nodo: N-73
# Arista: N-73-N-24
# Nodo: N-3
# Arista: N-3-N-75
# Nodo: N-36
# Arista: N-36-N-97
# Nodo: N-54
# Arista: N-54-N-0
# Nodo: N-37
# Arista: N-37-N-49
# Nodo: N-96
# Arista: N-96-N-38
# Nodo: N-81
# Arista: N-81-N-44
# Nodo: N-0
# Arista: N-0-N-54
# Nodo: N-67
# Arista: N-67-N-75
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-91
# Arista: N-91-N-83
# Nodo: N-34
# Arista: N-34-N-40
# Nodo: N-97
# Arista: N-97-N-28
# Nodo: N-49
# Arista: N-49-N-93
# Nodo: N-38
# Arista: N-38-N-85
# Nodo: N-24
# Arista: N-24-N-11
# Nodo: N-85
# Arista: N-85-N-49
# Nodo: N-44
# Arista: N-44-N-74
# Nodo: N-75
# Arista: N-75-N-91
# Nodo: N-95
# Arista: N-95-N-74
# Nodo: N-23
# Arista: N-23-N-0
# Nodo: N-93
# Arista: N-93-N-24
# ...

# %% [markdown]
# DFS_R Georgráfico 100 Nodos

# %%
g = Grafo("Geografico 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoGeografico 100-nodos NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoGeografico 100-nodos NoDir.gv en formato GraphViz a Grafo con nombre Geografico 100 nodos NoDir.
# Nodo: N-74
# Arista: N-74-N-37
# Nodo: N-73
# Arista: N-73-N-24
# Nodo: N-96
# Arista: N-96-N-38
# Nodo: N-3
# Arista: N-3-N-7
# Nodo: N-36
# Arista: N-36-N-97
# Nodo: N-37
# Arista: N-37-N-49
# Nodo: N-54
# Arista: N-54-N-23
# Nodo: N-81
# Arista: N-81-N-44
# Nodo: N-67
# Arista: N-67-N-17
# Nodo: N-11
# Arista: N-11-N-9
# Nodo: N-91
# Arista: N-91-N-83
# Nodo: N-34
# Arista: N-34-N-40
# Nodo: N-97
# Arista: N-97-N-28
# Nodo: N-38
# Arista: N-38-N-63
# Nodo: N-49
# Arista: N-49-N-85
# Nodo: N-24
# Arista: N-24-N-11
# Nodo: N-85
# Arista: N-85-N-38
# Nodo: N-44
# Arista: N-44-N-74
# Nodo: N-75
# Arista: N-75-N-3
# Nodo: N-95
# Arista: N-95-N-44
# Nodo: N-23
# Arista: N-23-N-28
# Nodo: N-93
# Arista: N-93-N-49
# Nodo: N-9
# Arista: N-9-N-0
# ...

# %% [markdown]
# BFS Gilbert 100 Nodos

# %%
g = Grafo("Gilbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoGilbert 100,0.4NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoGilbert 100,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 100 nodos NoDir.
# Nodo: N-88
# Arista: N-88-N-0
# Nodo: N-42
# Arista: N-42-N-0
# Nodo: N-13
# Arista: N-13-N-0
# Nodo: N-81
# Arista: N-81-N-0
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-4
# Arista: N-4-N-74
# Nodo: N-25
# Arista: N-25-N-74
# Nodo: N-68
# Arista: N-68-N-0
# Nodo: N-39
# Arista: N-39-N-74
# Nodo: N-34
# Arista: N-34-N-0
# Nodo: N-32
# Arista: N-32-N-74
# Nodo: N-10
# Arista: N-10-N-0
# Nodo: N-23
# Arista: N-23-N-0
# Nodo: N-61
# Arista: N-61-N-0
# Nodo: N-84
# Arista: N-84-N-42
# Nodo: N-9
# Arista: N-9-N-88
# Nodo: N-12
# Arista: N-12-N-0
# Nodo: N-86
# Arista: N-86-N-74
# Nodo: N-63
# Arista: N-63-N-0
# Nodo: N-77
# Arista: N-77-N-42
# Nodo: N-62
# Arista: N-62-N-0
# Nodo: N-98
# Arista: N-98-N-0
# Nodo: N-35
# Arista: N-35-N-0
# Nodo: N-70
# ...

# %% [markdown]
# DFS_I Gilbert 100 Nodos

# %%
g = Grafo("Gilbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoGilbert 100,0.4NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoGilbert 100,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 100 nodos NoDir.
# Nodo: N-88
# Arista: N-88-N-0
# Nodo: N-42
# Arista: N-42-N-0
# Nodo: N-13
# Arista: N-13-N-0
# Nodo: N-81
# Arista: N-81-N-0
# Nodo: N-11
# Arista: N-11-N-0
# Nodo: N-4
# Arista: N-4-N-92
# Nodo: N-25
# Arista: N-25-N-92
# Nodo: N-68
# Arista: N-68-N-0
# Nodo: N-39
# Arista: N-39-N-92
# Nodo: N-34
# Arista: N-34-N-0
# Nodo: N-32
# Arista: N-32-N-92
# Nodo: N-10
# Arista: N-10-N-0
# Nodo: N-23
# Arista: N-23-N-0
# Nodo: N-61
# Arista: N-61-N-0
# Nodo: N-84
# Arista: N-84-N-95
# Nodo: N-9
# Arista: N-9-N-72
# Nodo: N-12
# Arista: N-12-N-0
# Nodo: N-86
# Arista: N-86-N-92
# Nodo: N-63
# Arista: N-63-N-0
# Nodo: N-77
# Arista: N-77-N-98
# Nodo: N-62
# Arista: N-62-N-0
# Nodo: N-98
# Arista: N-98-N-0
# Nodo: N-35
# Arista: N-35-N-0
# Nodo: N-28
# ...

# %% [markdown]
# DFS_R Gilbert 100 Nodos

# %%
g = Grafo("Gilbert 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoGilbert 100,0.4NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoGilbert 100,0.4NoDir.gv en formato GraphViz a Grafo con nombre Gilbert 100 nodos NoDir.
# Nodo: N-74
# Arista: N-74-N-89
# Nodo: N-42
# Arista: N-42-N-15
# Nodo: N-73
# Arista: N-73-N-17
# Nodo: N-88
# Arista: N-88-N-83
# Nodo: N-36
# Arista: N-36-N-99
# Nodo: N-13
# Arista: N-13-N-20
# Nodo: N-54
# Arista: N-54-N-72
# Nodo: N-81
# Arista: N-81-N-79
# Nodo: N-11
# Arista: N-11-N-43
# Nodo: N-4
# Arista: N-4-N-33
# Nodo: N-55
# Arista: N-55-N-98
# Nodo: N-25
# Arista: N-25-N-73
# Nodo: N-68
# Arista: N-68-N-55
# Nodo: N-51
# Arista: N-51-N-84
# Nodo: N-91
# Arista: N-91-N-41
# Nodo: N-45
# Arista: N-45-N-95
# Nodo: N-39
# Arista: N-39-N-92
# Nodo: N-34
# Arista: N-34-N-31
# Nodo: N-52
# Arista: N-52-N-29
# Nodo: N-97
# Arista: N-97-N-49
# Nodo: N-60
# Arista: N-60-N-71
# Nodo: N-32
# Arista: N-32-N-80
# Nodo: N-8
# Arista: N-8-N-40
# Nodo: N-65
# ...

# %% [markdown]
# BFS Malla 100 Nodos

# %%
g = Grafo("Malla 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoMalla 10x10 NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.BFS(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoMalla 10x10 NoDir.gv en formato GraphViz a Grafo con nombre Malla 100 nodos NoDir.
# Nodo: N6,6
# Arista: N6,6-N5,6
# Nodo: N2,8
# Arista: N2,8-N1,8
# Nodo: N8,5
# Arista: N8,5-N7,5
# Nodo: N0,3
# Arista: N0,3-N0,2
# Nodo: N9,2
# Arista: N9,2-N8,2
# Nodo: N5,0
# Arista: N5,0-N4,0
# Nodo: N4,7
# Arista: N4,7-N4,6
# Nodo: N6,1
# Arista: N6,1-N6,0
# Nodo: N9,0
# Arista: N9,0-N8,0
# Nodo: N0,6
# Arista: N0,6-N0,5
# Nodo: N1,4
# Arista: N1,4-N1,3
# Nodo: N6,8
# Arista: N6,8-N5,8
# Nodo: N2,5
# Arista: N2,5-N1,5
# Nodo: N4,6
# Arista: N4,6-N3,6
# Nodo: N0,1
# Arista: N0,1-N0,0
# Nodo: N9,7
# Arista: N9,7-N8,7
# Nodo: N7,3
# Arista: N7,3-N7,2
# Nodo: N8,3
# Arista: N8,3-N8,2
# Nodo: N1,5
# Arista: N1,5-N0,5
# Nodo: N7,6
# Arista: N7,6-N6,6
# Nodo: N9,6
# Arista: N9,6-N9,5
# Nodo: N8,8
# Arista: N8,8-N8,7
# Nodo: N8,0
# Arista: N8,0-N7,0
# Nodo: N1,8
# ...

# %% [markdown]
# DFS_I Malla 100 Nodos

# %%
g = Grafo("Malla 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoMalla 10x10 NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_I(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoMalla 10x10 NoDir.gv en formato GraphViz a Grafo con nombre Malla 100 nodos NoDir.
# Nodo: N6,6
# Arista: N6,6-N7,6
# Nodo: N2,8
# Arista: N2,8-N2,9
# Nodo: N8,5
# Arista: N8,5-N9,5
# Nodo: N0,3
# Arista: N0,3-N0,2
# Nodo: N9,2
# Arista: N9,2-N9,3
# Nodo: N5,0
# Arista: N5,0-N6,0
# Nodo: N4,7
# Arista: N4,7-N5,7
# Nodo: N6,1
# Arista: N6,1-N7,1
# Nodo: N9,0
# Arista: N9,0-N9,1
# Nodo: N0,6
# Arista: N0,6-N0,5
# Nodo: N1,4
# Arista: N1,4-N0,4
# Nodo: N6,8
# Arista: N6,8-N6,9
# Nodo: N2,5
# Arista: N2,5-N3,5
# Nodo: N9,7
# Arista: N9,7-N9,8
# Nodo: N0,1
# Arista: N0,1-N0,0
# Nodo: N4,6
# Arista: N4,6-N5,6
# Nodo: N7,3
# Arista: N7,3-N8,3
# Nodo: N8,3
# Arista: N8,3-N9,3
# Nodo: N1,5
# Arista: N1,5-N0,5
# Nodo: N7,6
# Arista: N7,6-N8,6
# Nodo: N9,6
# Arista: N9,6-N9,7
# Nodo: N8,8
# Arista: N8,8-N8,9
# Nodo: N8,0
# Arista: N8,0-N9,0
# Nodo: N1,8
# ...

# %% [markdown]
# DFS_R Malla 100 Nodos

# %%
g = Grafo("Malla 100 nodos NoDir")
g.Cargar("C:\\Users\\jpach\\Documents\\GitHub\\DAA-B24\\Biblioteca de generación y manejo de grafos\\Archivos BFS y DFS\\100 Nodos\\GrafoMalla 10x10 NoDir.gv")

# g.MostrarGrafo()

nodo = g.nodos[0]

a = g.DFS_R(nodo)

a.MostrarGrafo()

a.Guardar()
# Out:
# Grafo cargado desde C:\Users\jpach\Documents\GitHub\DAA-B24\Biblioteca de generación y manejo de grafos\Archivos BFS y DFS\100 Nodos\GrafoMalla 10x10 NoDir.gv en formato GraphViz a Grafo con nombre Malla 100 nodos NoDir.
# Nodo: N6,2
# Arista: N6,2-N5,2
# Nodo: N6,6
# Arista: N6,6-N5,6
# Nodo: N8,5
# Arista: N8,5-N9,5
# Nodo: N2,8
# Arista: N2,8-N1,8
# Nodo: N1,6
# Arista: N1,6-N0,6
# Nodo: N2,4
# Arista: N2,4-N1,4
# Nodo: N4,9
# Arista: N4,9-N5,9
# Nodo: N2,6
# Arista: N2,6-N1,6
# Nodo: N3,1
# Arista: N3,1-N4,1
# Nodo: N0,3
# Arista: N0,3-N1,3
# Nodo: N4,4
# Arista: N4,4-N3,4
# Nodo: N5,6
# Arista: N5,6-N4,6
# Nodo: N2,0
# Arista: N2,0-N1,0
# Nodo: N3,0
# Arista: N3,0-N2,0
# Nodo: N9,2
# Arista: N9,2-N8,2
# Nodo: N3,2
# Arista: N3,2-N2,2
# Nodo: N5,0
# Arista: N5,0-N4,0
# Nodo: N3,5
# Arista: N3,5-N4,5
# Nodo: N8,7
# Arista: N8,7-N9,7
# Nodo: N4,7
# Arista: N4,7-N5,7
# Nodo: N0,5
# Arista: N0,5-N1,5
# Nodo: N6,1
# Arista: N6,1-N7,1
# Nodo: N4,0
# Arista: N4,0-N3,0
# Nodo: N9,0
# ...
